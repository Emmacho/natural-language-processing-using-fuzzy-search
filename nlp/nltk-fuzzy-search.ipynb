# %% [markdown]
# ### Import Python Packages

# %%
# import some standard python data packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and Explore Data

# %%
# load the test data csv file - this is the data to test quality

testdata = pd.read_csv("../datasets/test.csv")

# %%
# load the main address data csv file- this is the one to use to access data quality
alldata = pd.read_csv("../datasets/all_addresses.csv")

# %%
# prewview the testdata
testdata.head()
# Out:
#    uid            address           city state      zip
# 0    1      941 Thorpe St   Rock Springs    WY  82901.0
# 1    2     2809 HARRIS DR        Antioch    CA  94509.0
# 2    3  1441 Eastlake Ave    Los Angeles    CA  90033.0
# 3    4         7 ucayptus  Newport Beach    CA  92657.0
# 4    5    1400 Lachman Ln            NaN    CA  90272.0

# %%
# check the data type for text data
testdata.dtypes
# Out:
# uid         int64
# address    object
# city       object
# state      object
# zip        object
# dtype: object

# %%
# change the zip code to string object
testdata['zip'] = testdata['zip'].astype('Int64').astype('str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 # change the zip code to string object
# ----> 2 testdata['zip'] = testdata['zip'].astype('Int64').astype('str')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:80, in _astype_nansafe(arr, dtype, copy, skipna)
#      78 # dispatch on extension dtype if needed
#      79 if isinstance(dtype, ExtensionDtype):
# ---> 80     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      82 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      83     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:152, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     150 @classmethod
#     151 def _from_sequence(cls, scalars, *, dtype=None, copy: bool = False) -> Self:
# --> 152     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     153     return cls(values, mask)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/numeric.py:272, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     270 dtype_cls = cls._dtype_cls
#     271 default_dtype = dtype_cls._default_np_dtype
# --> 272 values, mask, _, _ = _coerce_to_data_and_mask(
#     273     value, dtype, copy, dtype_cls, default_dtype
#     274 )
#     275 return values, mask
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/numeric.py:227, in _coerce_to_data_and_mask(values, dtype, copy, dtype_cls, default_dtype)
#     223     values[mask] = cls._internal_fill_value
#     224 if inferred_type in ("string", "unicode"):
#     225     # casts from str are always safe since they raise
#     226     # a ValueError if the str cannot be parsed into a float
# --> 227     values = values.astype(dtype, copy=copy)
#     228 else:
#     229     values = dtype_cls._safe_cast(values, dtype, copy=False)
#
# ValueError: invalid literal for int() with base 10: '<NA>'

# %%
testdata.dtypes
# Out:
# uid         int64
# address    object
# city       object
# state      object
# zip        object
# dtype: object

# %%
testdata.head()
# Out:
#    uid            address           city state    zip
# 0    1      941 Thorpe St   Rock Springs    WY  82901
# 1    2     2809 HARRIS DR        Antioch    CA  94509
# 2    3  1441 Eastlake Ave    Los Angeles    CA  90033
# 3    4         7 ucayptus  Newport Beach    CA  92657
# 4    5    1400 Lachman Ln            NaN    CA  90272

# %%
# Check total size of the length of the data
len(testdata)
# Out:
# 99249

# %%
#Check if there are missing data in the testdata
missing_value = testdata.isnull().sum()
print(missing_value)
# Out:
# uid           0
# address       0
# city       1282
# state      7433
# zip           0
# dtype: int64

# %%
# Accumulate the missing data
testdata.isnull().sum().sum()
# Out:
# 8715

# %%
# preview alldata

alldata.head()
# Out:
#              address           city state    zip
# 0      941 Thorpe St   Rock Springs    WY  82901
# 1     2809 HARRIS DR        Antioch    CA  94509
# 2  1441 Eastlake Ave    Los Angeles    CA  90033
# 3       7 Eucalyptus  Newport Beach    CA  92657
# 4    1400 Lachman Ln    Los Angeles    CA  90272

# %%
# check data type

alldata.dtypes
# Out:
# address    object
# city       object
# state      object
# zip        object
# dtype: object

# %%
#check total size of the length of the dataset

len(alldata.index)
# Out:
# 130000

# %%
# check and print number of missing values in all data

print(alldata.isnull().sum())
# Out:
# address    295
# city        16
# state       16
# zip         16
# dtype: int64

# %%
#Check the total missing data in across the alldata dataset
alldata.isnull().sum().sum()
# Out:
# 343

# %% [raw]
# Note: Since the missing data are not huge, like the case of the testdata dataset, we can afford to remove the missing rows in the dataset

# %%
# drop all rows with missing values in alldata

alldata.dropna(axis=0, how='any')
# Out:
#                        address           city state    zip
# 0                941 Thorpe St   Rock Springs    WY  82901
# 1               2809 HARRIS DR        Antioch    CA  94509
# 2            1441 Eastlake Ave    Los Angeles    CA  90033
# 3                 7 Eucalyptus  Newport Beach    CA  92657
# 4              1400 Lachman Ln    Los Angeles    CA  90272
# ...                        ...            ...   ...    ...
# 129995        4477 Camrose Ave      San Diego    CA  92122
# 129996            13 STONEWALL         Irvine    CA  92620
# 129997        3456 Nouveau Way     Gold River    CA  95670
# 129998       9115 Bungalow Way      Elk Grove    CA  95758
# 129999  1824 Highlands View Rd         Alpine    CA  91901
#
# [129705 rows x 4 columns]

# %%
alldata.isnull().sum().sum()
# Out:
# 343

# %% [markdown]
# ### Format the address info in test and alladdress data
# The correctly formatted address is: street address, city, state zip (e.g. 710 Florida St, San Francisco, CA 94110)

# %%
# create column for full address of testdata

testdata['fulladdr'] = testdata['address'] + ', ' + testdata['city'] + ', ' + testdata['state'] + ' '+ testdata['zip']

# %%
# check the updated data
testdata.head(10)
# Out:
#    uid                     address           city state    zip  \
# 0    1               941 Thorpe St   Rock Springs    WY  82901
# 1    2              2809 HARRIS DR        Antioch    CA  94509
# 2    3           1441 Eastlake Ave    Los Angeles    CA  90033
# 3    4                  7 ucayptus  Newport Beach    CA  92657
# 4    5             1400 Lachman Ln            NaN    CA  90272
# 5    6          725 ounain View St       Altadena    CA  91001
# 6    7            1966 Clinton Ave       Calexico    CA  92231
# 7    8                  431 6th St     Sacramento    CA  95820
# 8    9        5574 Old Goodrich Rd       Clarence    NY  14031
# 9   10  3640 Oak Creek Dr, Unit 10        Ontario    CA  91761
#
#                                         fulladdr
# 0          941 Thorpe St, Rock Springs, WY 82901
# 1              2809 HARRIS DR, Antioch, CA 94509
# 2       1441 Eastlake Ave, Los Angeles, CA 90033
# 3            7 ucayptus, Newport Beach, CA 92657
# 4                                            NaN
# 5         725 ounain View St, Altadena, CA 91001
# 6           1966 Clinton Ave, Calexico, CA 92231
# 7               431 6th St, Sacramento, CA 95820
# 8       5574 Old Goodrich Rd, Clarence, NY 14031
# 9  3640 Oak Creek Dr, Unit 10, Ontario, CA 91761

# %% [raw]
# Note: for address in testdata with missing city or state info, the full address is NaN
#
# There are various things that can be done to clean this up such as trying to compare address,state, and zip for a match in all data and then fill the city with any information from all data. But for now, we would remove the fulladdr that are missing

# %%
# pick only rows where the full address is not null

testdata.dropna(axis=0, how='any', inplace=True)

# %%
testdata.head(10)
# Out:
#     uid                     address           city state    zip  \
# 0     1               941 Thorpe St   Rock Springs    WY  82901
# 1     2              2809 HARRIS DR        Antioch    CA  94509
# 2     3           1441 Eastlake Ave    Los Angeles    CA  90033
# 3     4                  7 ucayptus  Newport Beach    CA  92657
# 5     6          725 ounain View St       Altadena    CA  91001
# 6     7            1966 Clinton Ave       Calexico    CA  92231
# 7     8                  431 6th St     Sacramento    CA  95820
# 8     9        5574 Old Goodrich Rd       Clarence    NY  14031
# 9    10  3640 Oak Creek Dr, Unit 10        Ontario    CA  91761
# 10   11                Valencia Way  Valley Center    CA  92082
#
#                                          fulladdr
# 0           941 Thorpe St, Rock Springs, WY 82901
# 1               2809 HARRIS DR, Antioch, CA 94509
# 2        1441 Eastlake Ave, Los Angeles, CA 90033
# 3             7 ucayptus, Newport Beach, CA 92657
# 5          725 ounain View St, Altadena, CA 91001
# 6            1966 Clinton Ave, Calexico, CA 92231
# 7                431 6th St, Sacramento, CA 95820
# 8        5574 Old Goodrich Rd, Clarence, NY 14031
# 9   3640 Oak Creek Dr, Unit 10, Ontario, CA 91761
# 10          Valencia Way, Valley Center, CA 92082

# %%
# create column for full address of alldata

alldata['fulladdr'] = alldata['address'] + ', ' + alldata['city'] + ', ' + alldata['state'] + ' '+ alldata['zip']

# %%
# check the updated data
alldata.head(10)
# Out:
#                 address           city state    zip  \
# 0         941 Thorpe St   Rock Springs    WY  82901
# 1        2809 HARRIS DR        Antioch    CA  94509
# 2     1441 Eastlake Ave    Los Angeles    CA  90033
# 3          7 Eucalyptus  Newport Beach    CA  92657
# 4       1400 Lachman Ln    Los Angeles    CA  90272
# 5  725 Mountain View St       Altadena    CA  91001
# 6      1966 Clinton Ave       Calexico    CA  92231
# 7          4341 69th St     Sacramento    CA  95820
# 8  5574 Old Goodrich Rd       Clarence    NY  14031
# 9     3640 Oak Creek Dr        Ontario    CA  91761
#
#                                    fulladdr
# 0     941 Thorpe St, Rock Springs, WY 82901
# 1         2809 HARRIS DR, Antioch, CA 94509
# 2  1441 Eastlake Ave, Los Angeles, CA 90033
# 3     7 Eucalyptus, Newport Beach, CA 92657
# 4    1400 Lachman Ln, Los Angeles, CA 90272
# 5  725 Mountain View St, Altadena, CA 91001
# 6      1966 Clinton Ave, Calexico, CA 92231
# 7        4341 69th St, Sacramento, CA 95820
# 8  5574 Old Goodrich Rd, Clarence, NY 14031
# 9      3640 Oak Creek Dr, Ontario, CA 91761

# %% [raw]
# Address Matching
# coverage rate - the percentage of properties in a file that has correct addresses and matches up with a standard address database
#
# In order to check the full address matching, we would change the addresses in both testdata and alldata to lower case

# %%
# test data full address lower case

testdata['fulladdr'] =testdata['fulladdr'].str.lower()
testdata.head(10)
# Out:
#     uid                     address           city state    zip  \
# 0     1               941 Thorpe St   Rock Springs    WY  82901
# 1     2              2809 HARRIS DR        Antioch    CA  94509
# 2     3           1441 Eastlake Ave    Los Angeles    CA  90033
# 3     4                  7 ucayptus  Newport Beach    CA  92657
# 5     6          725 ounain View St       Altadena    CA  91001
# 6     7            1966 Clinton Ave       Calexico    CA  92231
# 7     8                  431 6th St     Sacramento    CA  95820
# 8     9        5574 Old Goodrich Rd       Clarence    NY  14031
# 9    10  3640 Oak Creek Dr, Unit 10        Ontario    CA  91761
# 10   11                Valencia Way  Valley Center    CA  92082
#
#                                          fulladdr
# 0           941 thorpe st, rock springs, wy 82901
# 1               2809 harris dr, antioch, ca 94509
# 2        1441 eastlake ave, los angeles, ca 90033
# 3             7 ucayptus, newport beach, ca 92657
# 5          725 ounain view st, altadena, ca 91001
# 6            1966 clinton ave, calexico, ca 92231
# 7                431 6th st, sacramento, ca 95820
# 8        5574 old goodrich rd, clarence, ny 14031
# 9   3640 oak creek dr, unit 10, ontario, ca 91761
# 10          valencia way, valley center, ca 92082

# %%
# alldata full address lower case

alldata['fulladdr'] = alldata['fulladdr'].str.lower()
alldata.head(10)
# Out:
#                 address           city state    zip  \
# 0         941 Thorpe St   Rock Springs    WY  82901
# 1        2809 HARRIS DR        Antioch    CA  94509
# 2     1441 Eastlake Ave    Los Angeles    CA  90033
# 3          7 Eucalyptus  Newport Beach    CA  92657
# 4       1400 Lachman Ln    Los Angeles    CA  90272
# 5  725 Mountain View St       Altadena    CA  91001
# 6      1966 Clinton Ave       Calexico    CA  92231
# 7          4341 69th St     Sacramento    CA  95820
# 8  5574 Old Goodrich Rd       Clarence    NY  14031
# 9     3640 Oak Creek Dr        Ontario    CA  91761
#
#                                    fulladdr
# 0     941 thorpe st, rock springs, wy 82901
# 1         2809 harris dr, antioch, ca 94509
# 2  1441 eastlake ave, los angeles, ca 90033
# 3     7 eucalyptus, newport beach, ca 92657
# 4    1400 lachman ln, los angeles, ca 90272
# 5  725 mountain view st, altadena, ca 91001
# 6      1966 clinton ave, calexico, ca 92231
# 7        4341 69th st, sacramento, ca 95820
# 8  5574 old goodrich rd, clarence, ny 14031
# 9      3640 oak creek dr, ontario, ca 91761

# %% [markdown]
# ### Check for Correct and Incorrect Addresseses

# %%
## Here is the magic of the "assign" function used. This will check the number of correct addresses in the test data and create a column add test to assign 0 or 1 if the address in test matches the all data address

testdata = testdata.assign(addtest=testdata.fulladdr.isin(alldata.fulladdr).astype(int))
testdata.head()
# Out:
#    uid             address           city state    zip  \
# 0    1       941 Thorpe St   Rock Springs    WY  82901
# 1    2      2809 HARRIS DR        Antioch    CA  94509
# 2    3   1441 Eastlake Ave    Los Angeles    CA  90033
# 3    4          7 ucayptus  Newport Beach    CA  92657
# 5    6  725 ounain View St       Altadena    CA  91001
#
#                                    fulladdr  addtest
# 0     941 thorpe st, rock springs, wy 82901        1
# 1         2809 harris dr, antioch, ca 94509        1
# 2  1441 eastlake ave, los angeles, ca 90033        1
# 3       7 ucayptus, newport beach, ca 92657        0
# 5    725 ounain view st, altadena, ca 91001        0

# %% [raw]
# Note: in the addtest column, the ones with value 1 are exact matches while the ones with 0 are not exact matches. We will do a value count to know the coverage rate

# %%
# Let's check number of 0 and 1 in the addtest

testdata['addtest'].value_counts()
# Out:
# addtest
# 1    62927
# 0    27607
# Name: count, dtype: int64

# %%
#Can we put it in percetage? How? count occurrence of each value in 'addtest' column as percentage of total
testdata.addtest.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# addtest
# 1    69.5%
# 0    30.5%
# Name: proportion, dtype: object

# %% [raw]
# Note: This means that 69.5% of address are a match but 30.5% are not a match. Hence coverage rate is 69.5%

# %% [markdown]
# ### Use Fuzzy Matching with python difflib to address the Incorrect Addresses¶

# %% [raw]
# The algorithm that we shall explore:
# 1. First, extract all testdata rows that have incorrect addresses indicated by addtest = 0
# 2. Take 20 rows out of 27607 in our processed dataset to save running time. Of course! You can try it with the whole dataset with a sacrifice of about 1.5 hours, subject to your machine capacity.

# %%
changetdata = testdata[testdata["addtest"] == 0]

changetdata.head()
# Out:
#     uid                     address           city state    zip  \
# 3     4                  7 ucayptus  Newport Beach    CA  92657
# 5     6          725 ounain View St       Altadena    CA  91001
# 7     8                  431 6th St     Sacramento    CA  95820
# 9    10  3640 Oak Creek Dr, Unit 10        Ontario    CA  91761
# 11   12           5571Moringside Dr        Clayton    CA  94517
#
#                                          fulladdr  addtest
# 3             7 ucayptus, newport beach, ca 92657        0
# 5          725 ounain view st, altadena, ca 91001        0
# 7                431 6th st, sacramento, ca 95820        0
# 9   3640 oak creek dr, unit 10, ontario, ca 91761        0
# 11           5571moringside dr, clayton, ca 94517        0

# %%
changetdata.shape
# Out:
# (27607, 7)

# %% [raw]
# There are 27,607 addresses with incorrect values.
#
# Note:
#
# Due to the large number of data that have errors and the limited amount of time for submission, I decided to test the difflib function with 20 copies of the incorrect addresses. Of course! You can try it all.

# %%
test01 = changetdata.head(20)

test01.head()
# Out:
#     uid                     address           city state    zip  \
# 3     4                  7 ucayptus  Newport Beach    CA  92657
# 5     6          725 ounain View St       Altadena    CA  91001
# 7     8                  431 6th St     Sacramento    CA  95820
# 9    10  3640 Oak Creek Dr, Unit 10        Ontario    CA  91761
# 11   12           5571Moringside Dr        Clayton    CA  94517
#
#                                          fulladdr  addtest
# 3             7 ucayptus, newport beach, ca 92657        0
# 5          725 ounain view st, altadena, ca 91001        0
# 7                431 6th st, sacramento, ca 95820        0
# 9   3640 oak creek dr, unit 10, ontario, ca 91761        0
# 11           5571moringside dr, clayton, ca 94517        0

# %% [raw]
# The Python package difflib is used to find close matches using the get_close_matches function
#
# find_addr: the function to run and match the searched address with addresses in alldata
#
# w = the address that we want to find a perfect match

# %%
import difflib

# function to perform fuzzy matching of incorrect addr with correct using difflib get_close_matches 
def find_addr(w):
    return difflib.get_close_matches(w, alldata.fulladdr.astype(str), n=1, cutoff=0.6)

# %%
# this loop through data in the testdata extracted and call the find function

for x in test01["fulladdr"]:   
    altadd = find_addr(x)
    test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])

test01.head(10)
# Out:
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
# /var/folders/bz/v121sbw15753l82s9fynnd9m0000gq/T/ipykernel_81648/529607151.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test01['fulladdr'] = test01['fulladdr'].replace(x, altadd[0])
#     uid                     address              city state    zip  \
# 3     4                  7 ucayptus     Newport Beach    CA  92657
# 5     6          725 ounain View St          Altadena    CA  91001
# 7     8                  431 6th St        Sacramento    CA  95820
# 9    10  3640 Oak Creek Dr, Unit 10           Ontario    CA  91761
# 11   12           5571Moringside Dr           Clayton    CA  94517
# 15   16               36 W aomi Ave           Arcadia    CA  91007
# 17   18          255 araise Flat Ln  South Lake Tahoe    CA  96150
# 19   20      129 Dexter St, Unit 20          La Habra    CA  90631
# 23   24               525 heynne Dr         San Dimas    CA  91773
# 27   28     1104 eatherwood Terrace         San Diego    CA  92131
#
#                                             fulladdr  addtest
# 3              7 eucalyptus, newport beach, ca 92657        0
# 5           725 mountain view st, altadena, ca 91001        0
# 7                 4341 69th st, sacramento, ca 95820        0
# 9               3640 oak creek dr, ontario, ca 91761        0
# 11            5571 morningside dr, clayton, ca 94517        0
# 15                365 w naomi ave, arcadia, ca 91007        0
# 17  255 paradise flat ln, south lake tahoe, ca 96150        0
# 19                 129 dexter st, la habra, ca 90631        0
# 23              525 cheyenne dr, san dimas, ca 91773        0
# 27    11004 weatherwood terrace, san diego, ca 92131        0

# %% [raw]
# Note: This function can correct some of the addresses by matching the testdata with the address in the alldata
#
# For example:
#
# Incorrect Address: 7 ucayptus, newport beach, ca 92657 (which is incorrect because of a typo)
#
# Correct Address: 7 eucalyptus, newport beach, ca 92657 (correct address)
#
# Another example:
#
# Incorrect: 725 ounain view st, altadena, ca 91001
#
# Correct: 725 mountain view st, altadena, ca 91001 (there was a typo in the address

# %%
## Check for the Coverage rate for the 100 extracted from incorrect addresses

test01 = test01.assign(newaddtest=test01.fulladdr.isin(alldata.fulladdr).astype(int))
test01.head()
# Out:
#     uid                     address           city state    zip  \
# 3     4                  7 ucayptus  Newport Beach    CA  92657
# 5     6          725 ounain View St       Altadena    CA  91001
# 7     8                  431 6th St     Sacramento    CA  95820
# 9    10  3640 Oak Creek Dr, Unit 10        Ontario    CA  91761
# 11   12           5571Moringside Dr        Clayton    CA  94517
#
#                                     fulladdr  addtest  newaddtest
# 3      7 eucalyptus, newport beach, ca 92657        0           1
# 5   725 mountain view st, altadena, ca 91001        0           1
# 7         4341 69th st, sacramento, ca 95820        0           1
# 9       3640 oak creek dr, ontario, ca 91761        0           1
# 11    5571 morningside dr, clayton, ca 94517        0           1

# %%
# check number of 0 and 1 in the newaddtest, just to keep the results
test01['newaddtest'].value_counts()
# Out:
# newaddtest
# 1    20
# Name: count, dtype: int64

# %%
#count occurrence of each value in 'newaddtest' column as percentage of total
test01.newaddtest.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# newaddtest
# 1    100.0%
# Name: proportion, dtype: object

# %% [raw]
# Note: We have 100 percent address correctness with the 100 piloted addresses
